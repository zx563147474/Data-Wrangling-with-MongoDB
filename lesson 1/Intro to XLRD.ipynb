# %%
import xlrd

# %%
datafile = "2013_ERCOT_Hourly_Load_Data.xls"

# %%
def parse_file(datafile):
    workbook = xlrd.open_workbook(datafile)
    sheet = workbook.sheet_by_index(0)

    data = [[sheet.cell_value(r, col) 
                for col in range(sheet.ncols)] 
                    for r in range(sheet.nrows)]

    print("\nList Comprehension")
    print("data[3][2]:", data[3][2])

    print("\nCells in a nested loop:")    
    for row in range(sheet.nrows):
        for col in range(sheet.ncols):
            if row == 50:
                print(sheet.cell_value(row, col))


                ### other useful methods:
                print("\nROWS, COLUMNS, and CELLS:")
                print("Number of rows in the sheet:", sheet.nrows)
                print("Type of data in cell","(",row, col,"):", sheet.cell_type(row, col))
                print("Value in cell ","(", row, col,"):", sheet.cell_value(row, col))
                print("Get a slice of values in column 3, from rows 1-3:", sheet.col_values(3, start_rowx=1, end_rowx=4))
                print("\nDATES:")
                print("Type of data in cell (row 1, col 0):", sheet.cell_type(1, 0))
                exceltime = sheet.cell_value(1, 0)
                print("Time in Excel format:", exceltime)
                print("Convert time to a Python datetime tuple, from the Excel float:", xlrd.xldate_as_tuple(exceltime, 0))

    return data

# %%
data = parse_file(datafile)
# Out:
# List Comprehension
# data[3][2]: 1036.0886969999988
#
# Cells in a nested loop:
# 41277.083333333336
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 0 ): 3
# Value in cell  ( 50 0 ): 41277.083333333336
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
# 9238.737309999968
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 1 ): 2
# Value in cell  ( 50 1 ): 9238.737309999968
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
# 1438.2052799999994
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 2 ): 2
# Value in cell  ( 50 2 ): 1438.2052799999994
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
# 1565.4428559999976
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 3 ): 2
# Value in cell  ( 50 3 ): 1565.4428559999976
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
# 916.7083480000003
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 4 ): 2
# Value in cell  ( 50 4 ): 916.7083480000003
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
# 14010.903488000036
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 5 ): 2
# Value in cell  ( 50 5 ): 14010.903488000036
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
# 3027.9833399999993
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 6 ): 2
# Value in cell  ( 50 6 ): 3027.9833399999993
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
# 6165.211119000006
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 7 ): 2
# Value in cell  ( 50 7 ): 6165.211119000006
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
# 1157.7416630000007
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 8 ): 2
# Value in cell  ( 50 8 ): 1157.7416630000007
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
# 37520.93340400001
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet: 7296
# Type of data in cell ( 50 9 ): 2
# Value in cell  ( 50 9 ): 37520.93340400001
# Get a slice of values in column 3, from rows 1-3: [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0): 3
# Time in Excel format: 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float: (2013, 1, 1, 1, 0, 0)
